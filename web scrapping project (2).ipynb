# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
URL="https://www.purplle.com/brand/purplle"
URL
# Out:
# 'https://www.purplle.com/brand/purplle'

# %%
r = requests.get(URL)
htmlcontent=r.content
print(htmlcontent)
# Out:
# b'<!DOCTYPE html><html lang="en"><head>\n  <meta http-equiv="Pragma" content="no-cache">\n  <meta http-equiv="Cache-Control" content="no-cache">\n  <meta http-equiv="Expires" content="-1">\n  <meta name="fragment" content="!">\n  <meta http-equiv="x-dns-prefetch-control" content="on">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n  \n  <link rel="manifest" href="/purplle.webmanifest">\n  <meta name="theme-color" content="#673ab7">\n  <!-- informs the browser that your page intends to establish a connection to another origin, and that you\xef\xbf\xbdd like the process to start as soon as possible. -->\n  <link rel="dns-prefetch" href="https://www.media4.ppl-media.com">\n\n  <link href="https://media6.ppl-media.com" rel="preconnect" crossorigin="">\n\n  <link href="https://static.criteo.net" rel="preconnect" crossorigin="">\n\n  <link href="https://www.google.co.in" rel="preconnect" crossorigin="">\n\n  <link href="https
# ...

# %%
soup = BeautifulSoup(htmlcontent,"html.parser")
print(soup)
soup.prettify
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="!" name="fragment"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="/purplle.webmanifest" rel="manifest"/>
# <meta content="#673ab7" name="theme-color"/>
# <!-- informs the browser that your page intends to establish a connection to another origin, and that you�d like the process to start as soon as possible. -->
# <link href="https://www.media4.ppl-media.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://media6.ppl-media.com" rel="preconnect"/>
# <link crossorigin="" href="https://static.criteo.net" rel="preconnect"/>
# <link crossorigin="" href="https://www.google.co.in" rel="preconnect"/>
# ...

# %%
product_name=soup.find_all(class_="pro-name el2 fanB")
print(product_name)
# Out:
# [<div _ngcontent-sc155="" class="pro-name el2 fanB">Purplle True Jewel 24K Gold Primer | Matte | Oil Control | Shine Control | Long Lasting | Lightweight | Pore Minimising | Dermatologically Tested - (20 ml)</div>, <div _ngcontent-sc155="" class="pro-name el2 fanB">Purplle Snail Mucin Instant Hydration Serum | All Skin Types | Anti-acne | Non-Sticky | Anti-aging | Collagen Production | Reduces Wrinkles | Glass Skin | Lightweight (30 ml)</div>, <div _ngcontent-sc155="" class="pro-name el2 fanB">Purplle Compact Powder with SPF For Wheatish Skin Be Your Own BFF|Long Lasting| Oil Contro| SPF Protection| Lightweight- Beige Self Care 3 (9 g)</div>, <div _ngcontent-sc155="" class="pro-name el2 fanB">Purplle Kajal, Winking Together - Black | Long Lasting | Pigmented | Water Resistent | Smudge Proof | Transfer Proof | Easy Application (0.30 g)</div>, <div _ngcontent-sc155="" class="pro-name el2 fanB">Purplle Ultra HD Matte Mini Liquid Lipstick, Red - My First Hook-up 11 | Highly Pigmented | N
# ...

# %%
product_names=[]
for i in range(0,len(product_name)):
    product_names.append(product_name[i].get_text())
print(product_names)
len(product_names)
# Out:
# ['Purplle True Jewel 24K Gold Primer | Matte | Oil Control | Shine Control | Long Lasting | Lightweight | Pore Minimising | Dermatologically Tested - (20 ml)', 'Purplle Snail Mucin Instant Hydration Serum | All Skin Types | Anti-acne | Non-Sticky | Anti-aging | Collagen Production | Reduces Wrinkles | Glass Skin | Lightweight (30 ml)', 'Purplle Compact Powder with SPF For Wheatish Skin Be Your Own BFF|Long Lasting| Oil Contro| SPF Protection| Lightweight- Beige Self Care 3 (9 g)', 'Purplle Kajal, Winking Together - Black | Long Lasting | Pigmented | Water Resistent | Smudge Proof | Transfer Proof | Easy Application (0.30 g)', 'Purplle Ultra HD Matte Mini Liquid Lipstick, Red - My First Hook-up 11 | Highly Pigmented | Non-drying | Long Lasting | Easy Application | Water Resistant | Transferproof | Smudgeproof (1.6 ml)', 'Purplle Fresh Dew Moisturiser with Squalane & Hyaluronic Acid | All Skin Types | Brightening | Hydrating | Anti-aging | Boosts Collagen Production (45 gm)', 'Purplle 
# ...

# %%
Discount_price=soup.find_all(class_="tx-0 f14 f18-d fanB")
print(Discount_price)
# Out:
# [<span _ngcontent-sc155="" class="tx-0 f14 f18-d fanB"><i _ngcontent-sc155="" class="p-rupee rupee-d pr f10 f12"></i>380</span>, <span _ngcontent-sc155="" class="tx-0 f14 f18-d fanB"><i _ngcontent-sc155="" class="p-rupee rupee-d pr f10 f12"></i>356</span>, <span _ngcontent-sc155="" class="tx-0 f14 f18-d fanB"><i _ngcontent-sc155="" class="p-rupee rupee-d pr f10 f12"></i>150</span>, <span _ngcontent-sc155="" class="tx-0 f14 f18-d fanB"><i _ngcontent-sc155="" class="p-rupee rupee-d pr f10 f12"></i>159</span>, <span _ngcontent-sc155="" class="tx-0 f14 f18-d fanB"><i _ngcontent-sc155="" class="p-rupee rupee-d pr f10 f12"></i>199</span>, <span _ngcontent-sc155="" class="tx-0 f14 f18-d fanB"><i _ngcontent-sc155="" class="p-rupee rupee-d pr f10 f12"></i>352</span>, <span _ngcontent-sc155="" class="tx-0 f14 f18-d fanB"><i _ngcontent-sc155="" class="p-rupee rupee-d pr f10 f12"></i>199</span>, <span _ngcontent-sc155="" class="tx-0 f14 f18-d fanB"><i _ngcontent-sc155="" class="p-rupee rupee-d p
# ...

# %%
Disc_price=[]
for i in range(0,len(Discount_price)):
    Disc_price.append(Discount_price[i].get_text())
print(Disc_price)
# Out:
# ['380', '356', '150', '159', '199', '352', '199', '157', '396', '201', '199', '124', '201', '201', '201', '211', '201', '201', '324', '559', '201', '404', '201', '201']

# %%
Og_price=soup.find_all(class_="tx-del mrl3 fanR fanM-d ng-star-inserted")
print(Og_price)
# Out:
# [<s _ngcontent-sc155="" class="tx-del mrl3 fanR fanM-d ng-star-inserted">₹475</s>, <s _ngcontent-sc155="" class="tx-del mrl3 fanR fanM-d ng-star-inserted">₹549</s>, <s _ngcontent-sc155="" class="tx-del mrl3 fanR fanM-d ng-star-inserted">₹225</s>, <s _ngcontent-sc155="" class="tx-del mrl3 fanR fanM-d ng-star-inserted">₹199</s>, <s _ngcontent-sc155="" class="tx-del mrl3 fanR fanM-d ng-star-inserted">₹249</s>, <s _ngcontent-sc155="" class="tx-del mrl3 fanR fanM-d ng-star-inserted">₹440</s>, <s _ngcontent-sc155="" class="tx-del mrl3 fanR fanM-d ng-star-inserted">₹249</s>, <s _ngcontent-sc155="" class="tx-del mrl3 fanR fanM-d ng-star-inserted">₹225</s>, <s _ngcontent-sc155="" class="tx-del mrl3 fanR fanM-d ng-star-inserted">₹440</s>, <s _ngcontent-sc155="" class="tx-del mrl3 fanR fanM-d ng-star-inserted">₹249</s>, <s _ngcontent-sc155="" class="tx-del mrl3 fanR fanM-d ng-star-inserted">₹249</s>, <s _ngcontent-sc155="" class="tx-del mrl3 fanR fanM-d ng-star-inserted">₹249</s>, <s _ngcontent
# ...

# %%
original_price=[]
for i in range(0,len(Og_price)):
    original_price.append(Og_price[i].get_text())
print(original_price)
# Out:
# ['₹475', '₹549', '₹225', '₹199', '₹249', '₹440', '₹249', '₹225', '₹440', '₹249', '₹249', '₹249', '₹249', '₹249', '₹249', '₹249', '₹249', '₹249', '₹499', '₹799', '₹249', '₹499', '₹249', '₹249']

# %%
Discount_percentage=soup.find_all(class_="tx-Grn fanR mrl3 fanM-d")
print(Discount_percentage)
# Out:
# [<span _ngcontent-sc155="" class="tx-Grn fanR mrl3 fanM-d">20% off</span>, <span _ngcontent-sc155="" class="tx-Grn fanR mrl3 fanM-d">35% off</span>, <span _ngcontent-sc155="" class="tx-Grn fanR mrl3 fanM-d">33% off</span>, <span _ngcontent-sc155="" class="tx-Grn fanR mrl3 fanM-d">20% off</span>, <span _ngcontent-sc155="" class="tx-Grn fanR mrl3 fanM-d">20% off</span>, <span _ngcontent-sc155="" class="tx-Grn fanR mrl3 fanM-d">20% off</span>, <span _ngcontent-sc155="" class="tx-Grn fanR mrl3 fanM-d">20% off</span>, <span _ngcontent-sc155="" class="tx-Grn fanR mrl3 fanM-d">30% off</span>, <span _ngcontent-sc155="" class="tx-Grn fanR mrl3 fanM-d">10% off</span>, <span _ngcontent-sc155="" class="tx-Grn fanR mrl3 fanM-d">19% off</span>, <span _ngcontent-sc155="" class="tx-Grn fanR mrl3 fanM-d">20% off</span>, <span _ngcontent-sc155="" class="tx-Grn fanR mrl3 fanM-d">50% off</span>, <span _ngcontent-sc155="" class="tx-Grn fanR mrl3 fanM-d">19% off</span>, <span _ngcontent-sc155="" class="tx
# ...

# %%
Desc_percentage=[]
for i in range(0,len(Discount_percentage)):
    Desc_percentage.append(Discount_percentage[i].get_text())
print(Desc_percentage)
# Out:
# ['20% off', '35% off', '33% off', '20% off', '20% off', '20% off', '20% off', '30% off', '10% off', '19% off', '20% off', '50% off', '19% off', '19% off', '19% off', '15% off', '19% off', '19% off', '35% off', '30% off', '19% off', '19% off', '19% off', '19% off']

# %%
rating_count=soup.find_all(class_="tx-med1 mrl5 f10 fanB f13-d ng-star-inserted")
print(Review_star)
# Out:
# [<span _ngcontent-sc155="" class="listTheme tr-box bg-lime ng-star-inserted"> 4 <i _ngcontent-sc155="" class="p-star2 mrl3 f9"></i></span>, <span _ngcontent-sc155="" class="listTheme tr-box bg-lime ng-star-inserted"> 3.9 <i _ngcontent-sc155="" class="p-star2 mrl3 f9"></i></span>, <span _ngcontent-sc155="" class="listTheme tr-box bg-lime ng-star-inserted"> 3.9 <i _ngcontent-sc155="" class="p-star2 mrl3 f9"></i></span>, <span _ngcontent-sc155="" class="listTheme tr-box bg-lime ng-star-inserted"> 3.9 <i _ngcontent-sc155="" class="p-star2 mrl3 f9"></i></span>, <span _ngcontent-sc155="" class="listTheme tr-box bg-lime ng-star-inserted"> 3.9 <i _ngcontent-sc155="" class="p-star2 mrl3 f9"></i></span>, <span _ngcontent-sc155="" class="listTheme tr-box bg-lime ng-star-inserted"> 3.9 <i _ngcontent-sc155="" class="p-star2 mrl3 f9"></i></span>, <span _ngcontent-sc155="" class="listTheme tr-box bg-lime ng-star-inserted"> 3.9 <i _ngcontent-sc155="" class="p-star2 mrl3 f9"></i></span>, <span _ngcon
# ...

# %%
ratings_count=[]
for i in range(0,len(rating_count)):
    ratings_count.append(rating_count[i].get_text())
print(ratings_count)
# Out:
# [' 3169 Ratings', ' 323 Ratings', ' 5471 Ratings', ' 2402 Ratings', ' 23488 Ratings', ' 242 Ratings', ' 23488 Ratings', ' 5471 Ratings', ' 206 Ratings', ' 23488 Ratings', ' 23488 Ratings', ' 23488 Ratings', ' 23488 Ratings', ' 23488 Ratings', ' 23488 Ratings', ' 23488 Ratings', ' 23488 Ratings', ' 23488 Ratings', ' 154 Ratings', ' 1889 Ratings', ' 23488 Ratings', ' 3169 Ratings', ' 23488 Ratings', ' 23488 Ratings']

# %%
import pandas as pd
Purple_lipstick = pd.DataFrame ({"product_name": product_names,"Discount_price": Disc_price,"Og_price": original_price,"Discount_percentage": Desc_percentage,"rating_count": ratings_count},index=range(1,len(rating_count)+1)) 
print(Purple_lipstick)
# Out:
#                                          product_name Discount_price Og_price  \
# 1   Purplle True Jewel 24K Gold Primer | Matte | O...            380     ₹475
# 2   Purplle Snail Mucin Instant Hydration Serum | ...            356     ₹549
# 3   Purplle Compact Powder with SPF For Wheatish S...            150     ₹225
# 4   Purplle Kajal, Winking Together - Black | Long...            159     ₹199
# 5   Purplle Ultra HD Matte Mini Liquid Lipstick, R...            199     ₹249
# 6   Purplle Fresh Dew Moisturiser with Squalane & ...            352     ₹440
# 7   Purplle Ultra HD Matte Mini Liquid Lipstick, B...            199     ₹249
# 8   Purplle Compact Powder with SPF For Wheatish S...            157     ₹225
# 9   Purplle Collagen Boosting Eternal Spring Night...            396     ₹440
# 10  Purplle Ultra HD Matte Mini Liquid Lipstick, P...            201     ₹249
# 11  Purplle Ultra HD Matte Mini Liquid Lipstick, P...            199     ₹249
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Acer'

# %%
Purple_lipstick.to_csv("Purple lipsticks.csv", index="false")
a=pd.read_csv("Purple lipsticks.csv")
a
# Out:
#     Unnamed: 0                                       product_name  \
# 0            1  Purplle True Jewel 24K Gold Primer | Matte | O...
# 1            2  Purplle Snail Mucin Instant Hydration Serum | ...
# 2            3  Purplle Compact Powder with SPF For Wheatish S...
# 3            4  Purplle Kajal, Winking Together - Black | Long...
# 4            5  Purplle Ultra HD Matte Mini Liquid Lipstick, R...
# 5            6  Purplle Fresh Dew Moisturiser with Squalane & ...
# 6            7  Purplle Ultra HD Matte Mini Liquid Lipstick, B...
# 7            8  Purplle Compact Powder with SPF For Wheatish S...
# 8            9  Purplle Collagen Boosting Eternal Spring Night...
# 9           10  Purplle Ultra HD Matte Mini Liquid Lipstick, P...
# 10          11  Purplle Ultra HD Matte Mini Liquid Lipstick, P...
# 11          12  Purplle Ultra HD Matte Mini Liquid Lipstick| L...
# 12          13  Purplle Ultra HD Matte Mini Liquid Lipstick, R...
# ...
